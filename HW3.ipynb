# %%
from FourierSeries import *

# %%
k = lambda x: (sp.Abs(x))#**1.5
L = sp.pi
p4 = FourierSeries(k, L, series_type=None)
p4._calculate_a(3)
# p4.plot_f_series_range().show()

# %%
(1/2*L)*sp.integrate(abs(x), (x,-L,L))
# Out:
# 0.5*pi**3

# %%
p4.plot_f_series_range().show()

# %%
ex = FourierSeries(lambda x: sp.cos(x), sp.pi, series_type='sin')

# %%
ex.plot_f_series_range(3,10, scale = 1).show()

# %%
ex.series(10)
# Out:
# 8*sin(2*x)/(3*pi) + 16*sin(4*x)/(15*pi) + 24*sin(6*x)/(35*pi) + 32*sin(8*x)/(63*pi) + 40*sin(10*x)/(99*pi)

# %% [markdown]
# ### Problem 1

# %%
x = sp.Symbol('x')
L = sp.Symbol('L')
n = sp.Symbol('n', integer = True, positive = True)
sp.nsimplify((2 / (L)) * sp.integrate(x**2 *
                                      sp.sin(n * x * sp.pi / L), (x, 0, L)))
# Out:
# 2*(-(-1)**n*L**3/(pi*n) + 2*(-1)**n*L**3/(pi**3*n**3) - 2*L**3/(pi**3*n**3))/L

# %%
f = lambda x: x * x
L = 1

# %%
N = 5
p1 = FourierSeries(f,L,series_type='sin')
p1.series(N)
# Out:
# (-8/pi**3 + 2/pi)*sin(pi*x) - sin(2*pi*x)/pi + (-8/(27*pi**3) + 2/(3*pi))*sin(3*pi*x) - sin(4*pi*x)/(2*pi) + (-8/(125*pi**3) + 2/(5*pi))*sin(5*pi*x)

# %%
p1.b[3]
# Out:
# -8/(27*pi**3) + 2/(3*pi)

# %%
min_coef = 1
max_coef = 10
p1.plot_f_series_range(min_coef=1,max_coef=5).show()

# %% [markdown]
# ### Problem 2

# %%
L = sp.pi
g = lambda x: -2*sp.sin(x)+3*sp.sin(5*x)-sp.sqrt(2)*sp.sin(6*x)
p2 = FourierSeries(g,L)
p2.series(6)
# Out:
# -2*sin(x) + 3*sin(5*x) - sqrt(2)*sin(6*x)

# %%
L = sp.pi

# %%
p2.plot_f_series_range(min_coef=1, max_coef=5).show()

# %% [markdown]
# ### Problem 3

# %%
h = lambda x: -x+1
L = sp.pi
p3 = FourierSeries(h, L)

# %%
# fourier_plot_multi(h, L, 1, 9,scale=3)
p3.plot_f_series_range(scale = 3).show()

# %%
k = lambda x: (sp.Abs(x))**1.5
L = sp.pi
p4 = FourierSeries(k,L)
p4.plot_f_series_range(scale = 3).show()

# %%
f(x)==f(-x)
# Out:
# True

# %%
k = lambda x: (sp.Abs(x))**1.5
L = sp.pi
p5 = FourierSeries(k, L, series_type='sin')
p5.plot_f_series_range(scale=3).show()

# %%
k = lambda x: (sp.Abs(x))**1.5
L = sp.pi
p6 = FourierSeries(k, L, series_type='cos')
p6.plot_f_series_range(scale=3).show()

# %%
L=1
sp.nsimplify((1 / (L)) * sp.integrate(abs(x) * sp.cos(1 * x * sp.pi /L), (x, -L, L)))
# Out:
# -4/pi**2

# %%
k(x)
# Out:
# Abs(x)**1.5
